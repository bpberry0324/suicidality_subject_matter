# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../datasets/full.csv')

# %%
ds = pd.concat([df[df['Subreddit'] == 0].sample(15_000), df[df['Subreddit'] == 1].sample(15_000)]).reset_index().drop(columns=['index'])

# %%
ds['Subreddit'].value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: Subreddit, dtype: float64

# %%
ds.shape
# Out:
# (30000, 9)

# %%
ds.tail(10)
# Out:
#        Subreddit                                           simp_lem  \
# 29990          1  thinking of killing myself because of lockdown...
# 29991          1  i almost cut myself i ve never done this befor...
# 29992          1  how do i tell a therapist that im suicidal wit...
# 29993          1  24 m living at home with parent nothing make m...
# 29994          1  if i kill myself doe it void my life insurance...
# 29995          1  life a an ugly male is not worth living i am 2...
# 29996          1  support i have been depressed for a long time ...
# 29997          1  i think it s time to say goodbye after losing ...
# 29998          1  got assaulted and life only suck a little bit ...
# 29999          1  i miss you i miss you so much i wish i could s...
#
#                                                 comp_lem  \
# 29990  thinking of killing myself because of lockdown...
# 29991  i almost cut myself i ’ve never done this befo...
# ...

# %%
ds.isnull().sum()
# Out:
# Subreddit         0
# simp_lem          0
# comp_lem          0
# unst_simp_lem     0
# unst_comp_lem     0
# simp_stem         0
# comp_stem         0
# unst_simp_stem    0
# unst_comp_stem    0
# dtype: int64

# %%
ds.to_csv('../../datasets/down_sample.csv', index = False)
