# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/lower_and_unstopped.csv')[['Subreddit']]

# %%
df['simp_lem'] = pd.read_csv('../../datasets/simp_lem.csv')['simp_lem']

# %%
df['comp_lem'] = pd.read_csv('../../datasets/comp_lem.csv')['comp_lem']

# %%
df['unst_simp_lem'] = pd.read_csv('../../datasets/unst_simp_lem.csv')['unst_simp_lem']

# %%
df['unst_comp_lem'] = pd.read_csv('../../datasets/unst_comp_lem.csv')['unst_comp_lem']

# %%
df['simp_stem'] = pd.read_csv('../../datasets/simp_stem.csv')['simp_stem']

# %%
df['comp_stem'] = pd.read_csv('../../datasets/comp_stem.csv')['comp_stem']

# %%
df['unst_simp_stem'] = pd.read_csv('../../datasets/unst_simp_stem.csv')['unst_simp_stem']

# %%
df['unst_comp_stem'] = pd.read_csv('../../datasets/unst_comp_stem.csv')['unst_comp_stem']

# %%
df.head()
# Out:
#    Subreddit                                           simp_lem  \
# 0          0  add diagnosis i recently got health insurance ...
# 1          1  question what should i tell my loved one when ...
# 2          0  any good advice ive tried very hard to overcom...
# 3          0  am i suffering from depression i feel unmotiva...
# 4          1  cada vez un poco más en la mierda he estado to...
#
#                                             comp_lem  \
# 0  add diagnosis ??? i recently got health insura...
# 1  question what should i tell my loved one when ...
# 2  any good advice ? ive tried very hard to overc...
# 3  am i suffering from depression ? i feel unmoti...
# 4  cada vez un poco más en la mierda he estado to...
#
#                                        unst_simp_lem  \
# 0  add diagnosis recently got health insurance sa...
# 1                question tell loved one actually it
# 2  any good advice ive tried hard overcome depres...
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (641939, 9)

# %%
df.tail(10)
# Out:
#         Subreddit                                           simp_lem  \
# 641944          0  found out my girlfriend is pregnant what do i ...
# 641945          1  i am gonna hold a knife up to my neck backstor...
# 641946          0  tfw the depression hit hard so it crept up on ...
# 641947          0  dont see the point in living i havent for a lo...
# 641948          0  pressure is destroying me when it come to scho...
# 641949          0  help for the depressed my boyfriend and i both...
# 641950          0  i dont think i know how to be happy for the la...
# 641951          0  how can i tell my doctor i need help i just re...
# 641952          1  so much built up i dont know where to start i ...
# 641953          1  not sure what to do ive never been in this sit...
#
#                                                  comp_lem  \
# 641944  found out my girlfriend is pregnant what do i ...
# 641945  i am gonna hold a knife up to my neck backstor...
# ...

# %%
df.to_csv('../../datasets/full.csv', index=False)
